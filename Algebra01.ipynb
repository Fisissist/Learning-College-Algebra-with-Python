# %% [markdown]
# # Propotions

# %% [markdown]
# $\frac{A}{B} = \frac{C}{D}$

# %%
"""
a = input("Enter A: ")
b = input("Enter B: ")
c = input("Enter C: ")
d = input("Enter D: ")
"""
a = 10
b = 20
c = 30
d = 00
#try:
if a == 00:
 ans = c * b / d
 print("A is:",ans)
elif b == 00:
  ans = a * d / c
  print("B is:",ans)
elif c == 00:
  ans = a * d / b
  print("C is:",ans)
elif d == 00:
  ans = c * b / a
  print("D is:",ans)
#except:
 # print("Please enter numerical value for variables or 00 for missing value.")
# Out:
# D is: 60.0

# %% [markdown]
# Attempted to make it usable but the if statements would not run
